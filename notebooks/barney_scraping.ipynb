# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nltk>=3.1 in /Users/barnabykempster/.pyenv/versions/3.10.6/envs/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /Users/barnabykempster/.pyenv/versions/3.10.6/envs/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /Users/barnabykempster/.pyenv/versions/3.10.6/envs/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/barnabykempster/.pyenv/versions/3.10.6/envs/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages (from nltk>=3.1->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/barnabykempster/.pyenv/versions/3.10.6/envs/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages (from nltk>=3.1->textblob) (4.66.1)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install newspaper3k
from newspaper import Article
import newspaper
from textblob import TextBlob
import nltk

from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
import pandas as pd

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = ['https://www.cnn.com/', 
       'https://www.foxnews.com/', 
       'https://www.washingtonpost.com/', 
       'https://www.reuters.com/',
      'https://www.dailyherald.com/']

new_data = news_scraper(link_lst)
# Out:
# links from https://www.cnn.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.foxnews.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.washingtonpost.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.reuters.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.dailyherald.com/ = 0
# Total Links -  0
# **Finished Parsing**

# %%
if new_data['link'].str.contains('foxsnews'):
    new_data['label'] = 1

# %%
new_data
# Out:
#                                                 link      pdate  \
# 0  https://www.foxnews.com/us/missing-wisconsin-f...        NaT
# 1  https://www.foxnews.com/us/advocates-call-focu...        NaT
# 2  http://www.foxnews.com/us/missing-wisconsin-fi...        NaT
# 3  http://www.foxnews.com/us/advocates-call-focus...        NaT
# 4  https://www.washingtonpost.com/world/2023/11/2... 2023-11-28
# 5  https://www.reuters.com/world/india/india-tunn... 2023-11-28
# 6  https://reuters.com/world/india/india-tunnel-w... 2023-11-28
# 7  https://www.reuters.com/markets/currency-clash... 2023-11-27
# 8  https://www.dailyherald.com/submitted/20231128... 2023-11-28
# 9  http://www.dailyherald.com/submitted/20231128/... 2023-11-28
#
#                                                title  \
# 0  Missing Wisconsin fisherman’s kayak found day ...
# 1  Advocates call for focus on housing solutions ...
# 2  Missing Wisconsin fisherman’s kayak found day ...
# 3  Advocates call for focus on housing solutions ...
# 4  Israel-Gaza war live updates CIA director in Q...
# 5  India tunnel workers could face PTSD after res...
# 6  India tunnel workers could face PTSD after res...
# 7  Currency clashes sour Russia's oil trade with ...
# 8  Harper College's Lifelong Learning Institute o...
# 9  Harper College's Lifelong Learning Institute o...
#
#                                               author  \
# 0                                   [Stephen Sorace]
# 1                                                 []
# 2                                   [Stephen Sorace]
# 3                                                 []
# 4                                                 []
# 5                                     [Shivam Patel]
# 6                                     [Shivam Patel]
# 7  [Elena Fabrichnaya Nidhi Verma Dmitry Zhdannik...
# 8             [Submitted Harper College News Bureau]
# 9             [Submitted Harper College News Bureau]
#
#                                                 text  \
# 0  An empty kayak belonging to a fisherman who we...
# 1  Tossing tent poles, blankets and a duffel bag ...
# 2  An empty kayak belonging to a fisherman who we...
# 3  Tossing tent poles, blankets and a duffel bag ...
# 4  Israel-Gaza war\n\nHostages: Hamas released 11...
# 5  A concrete block is carried into the tunnel wh...
# 6  A concrete block is carried into the tunnel wh...
# 7  Yang Mei Hu oil products tanker owned by COSCO...
# 8  Harper College's Lifelong Learning Institute o...
# 9  Harper College's Lifelong Learning Institute o...
#
#                                             keywords  \
# 0  [missing, search, sheriffs, teams, day, office...
# 1  [advocates, focus, escalate, housing, homeless...
# 2  [missing, search, sheriffs, teams, day, office...
# 3  [advocates, focus, escalate, housing, homeless...
# 4  [conflict, history, updates, talks, way, qatar...
# 5  [workers, trapped, dinakaran, face, sent, coll...
# 6  [workers, trapped, dinakaran, face, sent, coll...
# 7  [russias, currency, russian, oil, trade, sour,...
# 8  [members, institute, harper, program, learning...
# 9  [members, institute, harper, program, learning...
#
#                                     tags  compound    neg    neu    pos  \
# 0  {yet to be located., Missing Persons}   -0.8679  0.071  0.881  0.048
# 1                      {Homeless people}   -0.9985  0.103  0.826  0.071
# 2  {yet to be located., Missing Persons}   -0.8679  0.071  0.881  0.048
# 3                      {Homeless people}   -0.9985  0.103  0.826  0.071
# 4                                     {}   -0.9751  0.231  0.752  0.017
# 5                                     {}   -0.8663  0.107  0.808  0.085
# 6                                     {}   -0.8663  0.107  0.808  0.085
# 7                                     {}   -0.6493  0.054  0.899  0.047
# 8                                     {}    0.9984  0.017  0.842  0.140
# 9                                     {}    0.9984  0.017  0.842  0.140
#
#    polarity  subjectivity
# 0  0.002873      0.418619
# 1  0.054662      0.367020
# 2  0.002873      0.418619
# 3  0.054662      0.367020
# 4 -0.060000      0.870000
# 5 -0.022306      0.353803
# 6 -0.022306      0.353803
# 7  0.017381      0.308209
# 8  0.218408      0.470483
# 9  0.218408      0.470483
