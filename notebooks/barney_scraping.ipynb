# %%
# !pip install textblob

# %%
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install newspaper3k
from newspaper import Article
import newspaper
from textblob import TextBlob
import nltk

from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
import pandas as pd

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = ['https://www.cnn.com/', 
       'https://www.foxnews.com/', 
       'https://www.washingtonpost.com/', 
       'https://www.reuters.com/',
      'https://www.dailyherald.com/']

new_data = news_scraper(link_lst)
# Out:
# links from https://www.cnn.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.foxnews.com/ = 289
# Link Failed -  https://www.outkick.com/mike-mcdaniel-wife-story-al-michaels-response/
# Total Links -  289
# **Finished Parsing**
# links from https://www.washingtonpost.com/ = 120
# Link Failed -  https://www.washingtonpost.com/weather/2023/11/27/black-sea-storm-bettina-ukraine/
# Link Failed -  https://www.washingtonpost.com/nation/2023/11/28/google-maps-desert-detour-california-vegas-formula-one/
# Total Links -  409
# **Finished Parsing**
# links from https://www.reuters.com/ = 243
# Link Failed -  https://www.reuters.com/sports/rise-antisemitism-is-security-challenge-israeli-athletes-israel-committee-says-2023-11-28/
# Link Failed -  https://www.reuters.com/sports/golf/woods-frustrated-that-players-were-left-out-pga-liv-merger-talks-2023-11-29/
# Link Failed -  https://www.reuters.com/sports/cricket/dravid-gets-extension-india-coach-despite-world-cup-heartbreak-2023-11-29/
# Link Failed -  https://www.reuters.com/sports/womens-elite-sports-revenue-will-cross-billion-dollars-2024-deloitte-2023-11-29/
# Link Failed -  https://reuters.com/sports/rise-antisemitism-is-security-challenge-israeli-athletes-israel-committee-says-2023-11-28/
# Link Failed -  https://reuters.com/sports/golf/woods-frustrated-that-players-were-left-out-pga-liv-merger-talks-2023-11-29/
# Link Failed -  https://reuters.com/sports/cricket/dravid-gets-extension-india-coach-despite-world-cup-heartbreak-2023-11-29/
# Link Failed -  https://reuters.com/sports/womens-elite-sports-revenue-will-cross-billion-dollars-2024-deloitte-2023-11-29/
# Link Failed -  https://www.reuters.com/breakingviews/german-budget-crisis-will-haunt-economy-years-2023-11-24/
# Link Failed -  https://www.reuters.com/sports/britain-wins-litter-picking-world-cup-with-load-rubbish-2023-11-24/
# Total Links -  652
# **Finished Parsing**
# links from https://www.dailyherald.com/ = 244
# Link Failed -  https://www.dailyherald.com/news/obituaries/
# Link Failed -  http://www.dailyherald.com/news/obituaries/
# Total Links -  896
# **Finished Parsing**

# %%
new_data
# Out:
#                                                   link                pdate  \
# 0          https://www.foxnews.com/video/5614615980001                 None
# 1    https://www.foxnews.com/media/aoc-castigated-n...                 None
# 2    https://www.foxnews.com/sports/brawl-nhl-game-...                 None
# 3    https://www.foxnews.com/us/wisconsin-police-he...                 None
# 4    https://www.foxnews.com/video/topics/entertain...                 None
# ..                                                 ...                  ...
# 876  http://www.dailyherald.com/submitted/20231128/...  2023-10-30 00:00:00
# 877  http://www.dailyherald.com/submitted/20231128/...  2023-11-28 00:00:00
# 878  http://www.dailyherald.com/news/20231128/look-...  2023-11-27 00:00:00
# 879  http://www.dailyherald.com/news/20231124/image...  2023-11-27 00:00:00
# 880  http://www.dailyherald.com/news/20231121/look-...  2023-11-25 14:00:00
#
#                                                  title  \
# 0                        Watch Fox News Channel Online
# 1    AOC castigated for calling New York City unaff...
# 2    Brawl during NHL game results in unprecedented...
# 3    Wisconsin police help man stage marriage propo...
# 4                 Entertainment Videos and Video Clips
# ..                                                 ...
# 876  Look: The Week in Pictures photo gallery for O...
# 877  RE/MAX Suburban's holiday initiatives bring jo...
# 878  Brian Properties facilitates strategic acquisi...
# 879              Weed Ladies winter sale opens Nov. 30
# 880  147 apartments planned for downtown Winfield n...
#
#                            author  \
# 0                              []
# 1                  [Gabriel Hays]
# 2                 [Chantz Martin]
# 3                  [Michael Ruiz]
# 4                              []
# ..                            ...
# 876                 [John Starks]
# 877  [Submitted Danielle Perrott]
# 878   [Submitted Mark Meskauskas]
# 879  [Submitted Naper Settlement]
# 880                [Katlyn Smith]
#
#                                                   text  \
# 0    Log in to comment on videos and join in on the...
# 1    The New York Post editorial board ripped Rep. ...
# 2    Altercations can happen during an NHL game, bu...
# 3    Police are used to dealing with people on the ...
# 4    Log in to comment on videos and join in on the...
# ..                                                 ...
# 876  Brian Hill | Staff Photographer\n\nPalatine Hi...
# 877  RE/MAX Suburban's holiday initiatives bring jo...
# 878  Brian Properties facilitates strategic acquisi...
# 879  Weed Ladies winter sale opens Nov. 30\n\nFind ...
# 880  147 apartments planned for downtown Winfield n...
#
#                                               keywords  \
# 0    [comment, log, watch, join, videos, fox, chann...
# 1    [calling, blames, housing, rich, castigated, e...
# 2    [ice, senators, penalty, nhl, thrown, panthers...
# 3    [wisconsin, bodycam, marriage, help, goldschmi...
# 4    [comment, log, clips, join, videos, video, ent...
# ..                                                 ...
# 876  [2023, pictures, assistant, gallery, wellrespe...
# 877  [families, initiatives, bring, dec, suburbans,...
# 878  [park, estate, facilitates, district, brian, s...
# 879  [weed, nov, ladies, sale, 30, naper, floral, a...
# 880  [central, apartments, apartment, sorgatz, deve...
#
#                         tags  compound    neg    neu    pos  polarity  \
# 0                         {}    0.6705  0.000  0.645  0.355  0.300000
# 1    {climate change agenda}    0.9497  0.071  0.832  0.098  0.068590
# 2                         {}   -0.9100  0.092  0.830  0.077 -0.028416
# 3                         {}    0.9967  0.026  0.847  0.128  0.107941
# 4                         {}    0.6705  0.000  0.645  0.355  0.300000
# ..                       ...       ...    ...    ...    ...       ...
# 876                       {}    0.8402  0.000  0.867  0.133  0.325429
# 877                       {}    0.9992  0.005  0.739  0.257  0.191729
# 878                       {}    0.9969  0.002  0.862  0.136  0.140102
# 879                       {}    0.9803  0.007  0.886  0.107  0.192361
# 880                       {}    0.9960  0.006  0.906  0.088  0.088978
#
#      subjectivity
# 0        0.200000
# 1        0.433242
# 2        0.471292
# 3        0.420739
# 4        0.200000
# ..            ...
# 876      0.596952
# 877      0.358004
# 878      0.368668
# 879      0.595139
# 880      0.374448
#
# [881 rows x 13 columns]

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
new_data.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/scraped_data.csv")

# %%
if new_data['link'].str.contains('foxsnews'):
    new_data['label'] = 1
