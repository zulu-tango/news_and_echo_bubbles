# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
df_1 = pd.read_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/monday_zt_scrape.csv")
df_1
# Out:
#       Unnamed: 0                                               link pdate  \
# 0              0  https://www.propublica.org/article/inside-waba...   NaN
# 1              1  https://www.propublica.org/article/west-virgin...   NaN
# 2              2  https://www.propublica.org/article/texas-judge...   NaN
# 3              3  https://www.propublica.org/article/senate-judi...   NaN
# 4              4  https://www.propublica.org/article/clarence-th...   NaN
# ...          ...                                                ...   ...
# 3469        2082  http://www.theepochtimes.com/opinion/why-the-e...   NaN
# 3470        2083  http://www.theepochtimes.com/opinion/the-chine...   NaN
# 3471        2084  http://www.theepochtimes.com/opinion/the-chine...   NaN
# 3472        2085  http://www.theepochtimes.com/opinion/this-memo...   NaN
# 3473        2086  http://www.theepochtimes.com/opinion/this-memo...   NaN
#
#                                                   title  \
# ...

# %%
df_2 = pd.read_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/gg_data_mon.csv")
df_2
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://shop.nypost.com/collections/new-york-p...
# 1              1  https://nypost.com/2023/12/03/news/horrific-ne...
# 2              2  https://nypost.com/2023/12/03/news/rep-pramila...
# 3              3  https://nypost.com/2023/12/04/sports/deion-san...
# 4              4  https://nypost.com/2023/12/03/opinion/republic...
# ...          ...                                                ...
# 1478        1478  https://freebeacon.com/culture/what-makes-hama...
# 1479        1479  https://freebeacon.com/campus/portland-public-...
# 1480        1480  https://freebeacon.com/biden-administration/wa...
# 1481        1481  https://freebeacon.com/israel/watch-head-of-an...
# 1482        1482  https://freebeacon.com/enemies-of-freedom/enem...
#
#                           pdate  \
# 0                           NaN
# 1           2023-12-03 00:00:00
# 2           2023-12-03 00:00:00
# ...

# %%
df_3 = pd.read_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/monday_bk_scrape.csv")
df_3
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.theatlantic.com/international/arch...
# 1              1  https://www.theatlantic.com/ideas/archive/2023...
# 2              2  https://www.theatlantic.com/ideas/archive/2023...
# 3              3  https://www.theatlantic.com/culture/archive/20...
# 4              4  https://www.theatlantic.com/international/arch...
# ...          ...                                                ...
# 2751         931  https://www.cbsnews.com/video/saturday-session...
# 2752         932  https://www.cbsnews.com/video/saturday-session...
# 2753         933  https://www.cbsnews.com/video/author-sam-wasso...
# 2754         934  https://www.cbsnews.com/video/never-too-late-c...
# 2755         935  https://www.nytimes.com/2023/12/04/climate/cop...
#
#                           pdate  \
# 0     2023-12-02 13:00:00+00:00
# 1     2023-12-02 12:00:00+00:00
# 2     2023-12-02 11:00:00+00:00
# ...

# %%
combined_df = pd.concat([df_1,df_2,df_3], axis=0)
combined_df
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.propublica.org/article/inside-waba...
# 1              1  https://www.propublica.org/article/west-virgin...
# 2              2  https://www.propublica.org/article/texas-judge...
# 3              3  https://www.propublica.org/article/senate-judi...
# 4              4  https://www.propublica.org/article/clarence-th...
# ...          ...                                                ...
# 2751         931  https://www.cbsnews.com/video/saturday-session...
# 2752         932  https://www.cbsnews.com/video/saturday-session...
# 2753         933  https://www.cbsnews.com/video/author-sam-wasso...
# 2754         934  https://www.cbsnews.com/video/never-too-late-c...
# 2755         935  https://www.nytimes.com/2023/12/04/climate/cop...
#
#                     pdate                                              title  \
# ...

# %%
combined_df.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/monday_scrape_all.csv")
