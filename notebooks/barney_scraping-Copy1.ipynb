# %%
# !pip install textblob

# %%
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/barnabykempster/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install newspaper3k
from newspaper import Article
import newspaper
from textblob import TextBlob
import nltk

from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
import pandas as pd

# %%
provider_list = ['https://www.theatlantic.com/',
 'https://www.thedailybeast.com/',
 'https://www.huffpost.com/',
 'https://www.msnbc.com/',
 'https://www.nytimes.com/',
 'https://www.slate.com/',
 'https://www.vox.com/',
 'https://www.abcnews.go.com/',
 'https://www.apnews.com/',
 'https://www.bloomberg.com/',
 'https://www.cbsnews.com/',
 'https://www.nytimes.com/']

# %%
len(provider_list)
# Out:
# 12

# %%
first_list = provider_list[0:4]

# %%
second_list = provider_list[4:8]

# %%
third_list = provider_list[8:12]

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = first_list

new_data_1 = news_scraper(link_lst)
# Out:
# links from https://www.theatlantic.com/ = 272
# Link Failed -  https://www.theatlantic.com/newsletters/archive/2023/12/books-briefing-anthony-tommasini-recommendations/676205/
# Link Failed -  https://www.theatlantic.com/newsletters/archive/2023/11/books-briefing-justin-torres-blackouts/676036/
# Link Failed -  https://www.theatlantic.com/newsletters/archive/2023/10/books-briefing-10-books-recommendation-israel-hamas-war/675801/
# Link Failed -  https://www.theatlantic.com/family/archive/2023/10/can-chatgpt-use-slang/675828/
# Total Links -  272
# **Finished Parsing**
# links from https://www.thedailybeast.com/ = 50
# Link Failed -  https://www.thedailybeast.com/kate-middleton-gets-standing-ovation-as-king-defies-calls-to-strip-harrys-title?ref=home
# Total Links -  322
# **Finished Parsing**
# links from https://www.huffpost.com/ = 0
# Total Links -  322
# **Finished Parsing**
# links from https://www.msnbc.com/ = 81
# Total Links -  403
# **Finished Parsing**

# %%
new_data_1.head()
# Out:
#                                                 link  \
# 0  https://www.theatlantic.com/ideas/archive/2023...
# 1  https://www.theatlantic.com/culture/archive/20...
# 2  https://www.theatlantic.com/culture/archive/20...
# 3  https://www.theatlantic.com/ideas/archive/2023...
# 4  https://www.theatlantic.com/ideas/archive/2023...
#
#                       pdate  \
# 0 2023-12-01 15:00:00+00:00
# 1 2023-12-01 13:00:00+00:00
# 2 2023-12-01 13:00:00+00:00
# 3 2023-12-01 12:41:00+00:00
# 4 2023-12-01 12:31:00+00:00
#
#                                                title               author  \
# 0                Ron DeSantis Debates His Grievances         [David Frum]
# 1     May December Exposes the Art of Self-Deception         [Shirley Li]
# 2  She Made the Pop Album of the Year. But Is She...  [Spencer Kornhaber]
# 3                            Inflation Is Your Fault       [Annie Lowrey]
# 4                   What Kissinger Didn’t Understand      [George Packer]
#
# ...

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
new_data.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/scraped_data.csv")

# %%
if new_data['link'].str.contains('foxsnews'):
    new_data['label'] = 1

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = second_list

new_data_2 = news_scraper(link_lst)
# Out:
# links from https://www.nytimes.com/ = 200
# Link Failed -  https://www.nytimes.com/2023/12/01/dining/holiday-cookies.html
# Link Failed -  https://cooking.nytimes.com/recipes/1024143-cauliflower-pasta-with-anchovies-and-bread-crumbs
# Link Failed -  https://cooking.nytimes.com/recipes/1024226-roasted-red-peppers-with-beans-and-greens
# Total Links -  200
# **Finished Parsing**
# links from https://www.slate.com/ = 0
# Total Links -  200
# **Finished Parsing**
# links from https://www.vox.com/ = 388
# Total Links -  588
# **Finished Parsing**
# links from https://www.abcnews.go.com/ = 0
# Total Links -  588
# **Finished Parsing**

# %%
new_data_2.head()
# Out:
#                                                 link                pdate  \
# 0     https://www.nytimes.com/section/business/media                 None
# 1  https://www.nytimes.com/interactive/2023/10/27...  2023-10-27 00:00:00
# 2  https://www.nytimes.com/2023/10/19/podcasts/se...  2023-10-19 00:00:00
# 3  https://www.nytimes.com/article/submit-crosswo...                 None
# 4  https://www.nytimes.com/2022/09/19/crosswords/...  2022-09-19 00:00:00
#
#                                                title  \
# 0                                              Media
# 1                   5 Minutes to Make You Love Music
# 2  From Serial Productions: The Kids of Rutherfor...
# 3  Submit Your Crossword Puzzles to The New York ...
# 4                   How to Solve Beginner Crosswords
#
#                                               author  \
# 0                                                 []
# 1                                                 []
# ...

# %%
#block-views-story-id-boxs-block > div > div > div > div.news-item.right > a.source-area > img

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]
    rating = []

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
                rating.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity,rating))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity','rating'])
    
    return d1


link_lst = third_list

new_data_3 = news_scraper(link_lst)
# Out:
# links from https://www.apnews.com/ = 124
# Link Failed -  https://apnews.com/article/russia-lgbtq-crackdown-extremist-supreme-court-1b8f4cd8708d1c6cf3486c5f27fd7354
# Total Links -  124
# **Finished Parsing**
# links from https://www.bloomberg.com/ = 298
# Link Failed -  https://www.bloomberg.com/company/press/
# Link Failed -  https://www.bloomberg.com/features/where-to-go-2023-luxury-travel-vacations-hotels-restaurants/
# Link Failed -  https://www.bloomberg.com/news/articles/2023-12-01/bezos-fund-targets-methane-from-cows-with-57-million-in-food-focused-grants
# Link Failed -  https://www.bloomberg.com/news/articles/2023-12-01/binance-vip-traders-got-sneak-peek-of-record-us-crypto-penalty
# Link Failed -  https://www.bloomberg.com/news/articles/2023-11-29/ftx-approved-to-start-selling-744-million-in-grayscale-assets
# Link Failed -  https://www.bloomberg.com/news/articles/2023-12-01/citi-hsbc-top-record-list-of-bank-executives-going-to-cop-talks?srnd=premium-uk
# ...

# %%
new_data_3.head()
# Out:
#                                                 link               pdate  \
# 0  https://apnews.com/hub/ap-top-25-college-footb...                 NaT
# 1  https://apnews.com/article/israel-hamas-war-li... 2023-12-01 05:27:30
# 2  https://apnews.com/article/supreme-court-oconn... 2023-12-01 15:02:15
# 3  https://apnews.com/article/cowboys-seahawks-sc... 2023-12-01 04:51:26
# 4  https://apnews.com/article/warren-buffett-hasl... 2023-11-30 23:33:29
#
#                                                title  \
# 0  NCAA College Football Rankings: AP Top 25 Foot...
# 1  Live updates | Israel and Hamas trade blame fo...
# 2  Retired Justice Sandra Day O’Connor, the first...
# 3  Dak Prescott throws for 3 TDs, Cowboys extend ...
# 4  Haslam family refutes allegation from Warren B...
#
#                                               author  \
# 0                                                 []
# 1                                                 []
# ...

# %%
concat_df = pd.concat([new_data_1, new_data_2, new_data_3], axis=0)

# %%
concat_df.drop(columns='rating')
# Out:
#                                                   link  \
# 0    https://www.theatlantic.com/ideas/archive/2023...
# 1    https://www.theatlantic.com/culture/archive/20...
# 2    https://www.theatlantic.com/culture/archive/20...
# 3    https://www.theatlantic.com/ideas/archive/2023...
# 4    https://www.theatlantic.com/ideas/archive/2023...
# ..                                                 ...
# 877  https://www.cbsnews.com/video/nyt-cooking-reci...
# 878  https://www.cbsnews.com/video/nyt-cooking-reci...
# 879  https://www.cbsnews.com/video/nyt-cooking-reci...
# 880  https://www.cbsnews.com/video/the-dish-recipe-...
# 881  https://www.cbsnews.com/video/easy-to-follow-5...
#
#                          pdate  \
# 0    2023-12-01 15:00:00+00:00
# 1    2023-12-01 13:00:00+00:00
# 2    2023-12-01 13:00:00+00:00
# 3    2023-12-01 12:41:00+00:00
# 4    2023-12-01 12:31:00+00:00
# ..                         ...
# 877                        NaT
# 878                        NaT
# ...

# %%
concat_df
# Out:
#                                                   link  \
# 0    https://www.theatlantic.com/ideas/archive/2023...
# 1    https://www.theatlantic.com/culture/archive/20...
# 2    https://www.theatlantic.com/culture/archive/20...
# 3    https://www.theatlantic.com/ideas/archive/2023...
# 4    https://www.theatlantic.com/ideas/archive/2023...
# ..                                                 ...
# 877  https://www.cbsnews.com/video/nyt-cooking-reci...
# 878  https://www.cbsnews.com/video/nyt-cooking-reci...
# 879  https://www.cbsnews.com/video/nyt-cooking-reci...
# 880  https://www.cbsnews.com/video/the-dish-recipe-...
# 881  https://www.cbsnews.com/video/easy-to-follow-5...
#
#                          pdate  \
# 0    2023-12-01 15:00:00+00:00
# 1    2023-12-01 13:00:00+00:00
# 2    2023-12-01 13:00:00+00:00
# 3    2023-12-01 12:41:00+00:00
# 4    2023-12-01 12:31:00+00:00
# ..                         ...
# 877                        NaT
# 878                        NaT
# ...

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
concat_df.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/BK_fri_scrape.csv")

# %%
import requests
from bs4 import BeautifulSoup

link_temp = 'https://www.allsides.com/story/middle-east-top-cia-official-posted-pro-palestine-image-her-facebook-profile'

def scraping_temp(link_):
    left_article_title = []
    left_article_publisher = []
    left_article_link = []


    center_article_title = []
    center_article_publisher = []
    center_article_link = []

    right_article_title = []
    right_article_publisher = []
    right_article_link = []
    
    response = requests.get(link_)
    soup = BeautifulSoup(response.text, 'html.parser')
    for elem in soup.find_all('div', attrs={'class': 'news-item left'}):
        link = elem.find('a')['href']
        article_text = elem.find('a').text
        dis = elem.find('span').text
        left_article_title.append(article_text)
        left_article_publisher.append(dis)
        left_article_link.append(link)

    for elem in soup.find_all('div', attrs={'class': 'news-item center'}):
        link = elem.find('a')['href']
        article_text = elem.find('a').text
        dis = elem.find('span').text
        center_article_title.append(article_text)
        center_article_publisher.append(dis)
        center_article_link.append(link)

    for elem in soup.find_all('div', attrs={'class': 'news-item right'}):
        link = elem.find('a')['href']
        article_text = elem.find('a').text
        dis = elem.find('span').text
        right_article_title.append(article_text)
        right_article_publisher.append(dis)
        right_article_link.append(link)


    left_df = pd.DataFrame(list(zip(left_article_title, left_article_publisher, left_article_link)))
    left_df['classifier'] = 'left'
    center_df = pd.DataFrame(list(zip(center_article_title, center_article_publisher, center_article_link)))
    center_df['classifier'] = 'center'
    right_df = pd.DataFrame(list(zip(right_article_title, right_article_publisher, right_article_link)))
    right_df['classifier'] = 'right'

    return pd.concat([left_df, center_df, right_df]).reset_index(drop=True)

# %%
df_US_economy = scraping_temp('https://www.allsides.com/news/2023-11-21-1547/middle-east-israeli-prime-minister-netanyahu-says-war-against-hamas-will-not')
df_US_economy.head()
# Out:
#                                                    0                  1  \
# 0  \n\n\n   Deal reached to extend Israel-Hamas t...  CNN (Online News)
# 1  \n\n   US says Somali pirates likely behind at...         Al Jazeera
# 2  \n\n   Qatar is the go-to mediator in the Mide...   Associated Press
# 3  \n\n   Antisemites supporting Israel is weird....       The Guardian
# 4  \n\n   Elon Musk Visits Israel Amid Gaza Cease...            Haaretz
#
#                                                    2 classifier
# 0  https://www.allsides.com/news/2023-11-28-0517/...       left
# 1  https://www.allsides.com/news/2023-11-28-0259/...       left
# 2  https://www.allsides.com/news/2023-11-27-1528/...       left
# 3  https://www.allsides.com/news/2023-11-27-0920/...       left
# 4  https://www.allsides.com/news/2023-11-27-0405/...       left

# %% [markdown]
# soup.find('div', attrs={'class': 'news-item left'}).find('span').text

# %% [markdown]
# article_text = soup.find('div', attrs={'class': 'news-item left'}).find('a').text
# dis = soup.find('div', attrs={'class': 'news-item left'}).find('span').text

# %%
df_trump_obamacare = scraping_temp('https://www.allsides.com/story/healthcare-trump-looking-alternatives-obamacare-if-elected-2024')
df_trump_obamacare.head()
# Out:
#                                                    0                      1  \
# 0  Biden Campaign Aims to Weaponize Trump’s Threa...  New York Times (News)
# 1  \n\n\n   Team Biden plots attack on Trump over...                Semafor
# 2  \n\n   Medical provider vying for border contr...        Washington Post
# 3  \n\n   Why are so few people getting the lates...                    Vox
# 4  \n\n   Patients don’t know how to navigate the...                    Vox
#
#                                                    2 classifier
# 0  https://www.allsides.com/news/2023-11-27-1458/...       left
# 1  https://www.allsides.com/news/2023-11-27-1149/...       left
# 2  https://www.allsides.com/news/2023-11-21-1012/...       left
# 3  https://www.allsides.com/news/2023-11-17-0731/...       left
# 4  https://www.allsides.com/news/2023-11-03-0706/...       left

# %%
df_hunter_biden = scraping_temp('https://www.allsides.com/story/politics-oversight-committee-subpoenas-hunter-and-james-biden-impeachment-probe')
df_hunter_biden.head()
# Out:
#                                                    0                      1  \
# 0  House Republicans Subpoena Biden’s Son and Bro...  New York Times (News)
# 1  \n\n   As Congress struggles, many members bai...                  MSNBC
# 2  \n\n   Kevin McCarthy Brutally Fact-Checked Af...            Daily Beast
# 3  \n\n   The Hunter Biden counter-offensive: A s...               Politico
# 4  \n\n   US presidents and first ladies to gathe...      CNN (Online News)
#
#                                                    2 classifier
# 0  https://www.allsides.com/news/2023-11-08-1400/...       left
# 1  https://www.allsides.com/news/2023-11-28-1017/...       left
# 2  https://www.allsides.com/news/2023-11-28-1007/...       left
# 3  https://www.allsides.com/news/2023-11-28-0550/...       left
# 4  https://www.allsides.com/news/2023-11-28-0538/...       left

# %%
df_newsom_desantis = scraping_temp('https://www.allsides.com/story/politics-newsom-vs-desantis-debate-glimpse-america-s-political-future')
df_newsom_desantis.head()
# Out:
#                                                    0                  1  \
# 0  DeSantis v Newsom: the presidential match-up t...      The Economist
# 1  \n\n   As Congress struggles, many members bai...              MSNBC
# 2  \n\n   Kevin McCarthy Brutally Fact-Checked Af...        Daily Beast
# 3  \n\n   The Hunter Biden counter-offensive: A s...           Politico
# 4  \n\n   US presidents and first ladies to gathe...  CNN (Online News)
#
#                                                    2 classifier
# 0  https://www.allsides.com/news/2023-11-28-0853/...       left
# 1  https://www.allsides.com/news/2023-11-28-1017/...       left
# 2  https://www.allsides.com/news/2023-11-28-1007/...       left
# 3  https://www.allsides.com/news/2023-11-28-0550/...       left
# 4  https://www.allsides.com/news/2023-11-28-0538/...       left

# %%
combined_df = pd.concat([df_US_economy,df_trump_obamacare,df_hunter_biden,df_newsom_desantis])
combined_df
# Out:
#                                                     0  \
# 0   \n\n\n   Deal reached to extend Israel-Hamas t...
# 1   \n\n   US says Somali pirates likely behind at...
# 2   \n\n   Qatar is the go-to mediator in the Mide...
# 3   \n\n   Antisemites supporting Israel is weird....
# 4   \n\n   Elon Musk Visits Israel Amid Gaza Cease...
# ..                                                ...
# 43  \n\n   The Next Question Regarding This Israel...
# 44  \n\n   Suspended Adams aide told staffers to d...
# 45  \n\n   This Thanksgiving, America Is Being Ser...
# 46  \n\n   Trump medical report released as Biden ...
# 47  \n\n   Manchin risks getting 'exposed' in effo...
#
#                             1  \
# 0           CNN (Online News)
# 1                  Al Jazeera
# 2            Associated Press
# 3                The Guardian
# 4                     Haaretz
# ..                        ...
# 43                   Townhall
# 44       New York Post (News)
# 45  National Review (Opinion)
# ...

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
combined_df.to_csv('/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/all_sides.csv')

# %%
for link in combined_df[2]:
    print(link)
# Out:
# https://www.allsides.com/news/2023-11-28-0517/middle-east-deal-reached-extend-israel-hamas-truce-two-days-qatar-says
# https://www.allsides.com/news/2023-11-28-0259/middle-east-us-says-somali-pirates-likely-behind-attempted-tanker-seizure-near
# https://www.allsides.com/news/2023-11-27-1528/middle-east-qatar-go-mediator-mideast-war-its-unprecedented-tel-aviv-trip-saved
# https://www.allsides.com/news/2023-11-27-0920/middle-east-antisemites-supporting-israel-weird-jewish-support-them-even
# https://www.allsides.com/news/2023-11-27-0405/middle-east-elon-musk-visits-israel-amid-gaza-cease-fire-will-meet-netanyahu
# https://www.allsides.com/news/2023-11-25-0104/free-speech-how-pro-palestinian-campus-group-became-national-lightning-rod
# https://www.allsides.com/news/2023-11-25-0040/middle-east-first-group-israelis-and-palestinians-freed-under-breakthrough
# https://www.allsides.com/news/2023-11-24-0655/middle-east-why-israel-imprisons-so-many-palestinians
# ...

# %%
#block-views-article-page-redesign-block-1 > div > div > div > div.article-page-detail > div.second-portion > div.span8 > div.read-more-story > a

# %%
def article_text_grabber(list_of_links):
