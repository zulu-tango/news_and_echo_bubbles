# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Bring in list of webpages

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
df = pd.read_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/all_sides.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  \n\n\n   Deal reached to extend Israel-Hamas t...
# 1           1  \n\n   US says Somali pirates likely behind at...
# 2           2  \n\n   Qatar is the go-to mediator in the Mide...
# 3           3  \n\n   Antisemites supporting Israel is weird....
# 4           4  \n\n   Elon Musk Visits Israel Amid Gaza Cease...
#
#                    1                                                  2  \
# 0  CNN (Online News)  https://www.allsides.com/news/2023-11-28-0517/...
# 1         Al Jazeera  https://www.allsides.com/news/2023-11-28-0259/...
# 2   Associated Press  https://www.allsides.com/news/2023-11-27-1528/...
# 3       The Guardian  https://www.allsides.com/news/2023-11-27-0920/...
# 4            Haaretz  https://www.allsides.com/news/2023-11-27-0405/...
#
#   classifier
# 0       left
# 1       left
# 2       left
# 3       left
# 4       left

# %%
list_webpages = list(df['2'])

# %%
list_webpages
# Out:
# ['https://www.allsides.com/news/2023-11-28-0517/middle-east-deal-reached-extend-israel-hamas-truce-two-days-qatar-says',
#  'https://www.allsides.com/news/2023-11-28-0259/middle-east-us-says-somali-pirates-likely-behind-attempted-tanker-seizure-near',
#  'https://www.allsides.com/news/2023-11-27-1528/middle-east-qatar-go-mediator-mideast-war-its-unprecedented-tel-aviv-trip-saved',
#  'https://www.allsides.com/news/2023-11-27-0920/middle-east-antisemites-supporting-israel-weird-jewish-support-them-even',
#  'https://www.allsides.com/news/2023-11-27-0405/middle-east-elon-musk-visits-israel-amid-gaza-cease-fire-will-meet-netanyahu',
#  'https://www.allsides.com/news/2023-11-25-0104/free-speech-how-pro-palestinian-campus-group-became-national-lightning-rod',
#  'https://www.allsides.com/news/2023-11-25-0040/middle-east-first-group-israelis-and-palestinians-freed-under-breakthrough',
#  'https://www.allsides.com/news/2023-11-24-0655/middle-east-why-israel-imprisons-so-many-palestinians',
# ...

# %% [markdown]
# ### run driver to host chrome in selenium

# %%
DRIVER_PATH = '/path/to/chromedriver'
driver = webdriver.Chrome()
driver.get('https://google.com')

# %%
driver.get("https://www.allsides.com/news/2023-11-28-0517/middle-east-deal-reached-extend-israel-hamas-truce-two-days-qatar-says")
print(driver.page_source)
# Out:
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#" class="js"><head profile="http://www.w3.org/1999/xhtml/vocab"><meta http-equiv="origin-trial" content="">
# <meta charset="utf-8">
# ...

# %%
driver.implicitly_wait(1.0)

# %%
text_box = driver.find_element(by=By.CLASS_NAME, value="read-more-story")
# text_box.send_keys("Selenium")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 text_box = driver.find_element(by=By.CLASS_NAME, value="read-more-story")
#       2 # text_box.send_keys("Selenium")
#
# File ~/.pyenv/versions/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/.pyenv/versions/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %%
submit_button = driver.find_element(by=By.CSS_SELECTOR, value="button")

# %%
submit_button.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 submit_button.click()
#
# File ~/.pyenv/versions/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File ~/.pyenv/versions/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# --> 394 return self._parent.execute(command, params)
#
# File ~/.pyenv/versions/lewagon/envs/news_and_echo_bubbles/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
# ...

# %% [markdown]
# RUN BELOW TO QUIT THE DRIVER, ONLY WHEN DONE

# %%
#driver.quit()
