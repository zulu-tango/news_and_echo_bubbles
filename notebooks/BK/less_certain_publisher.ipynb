# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
df = pd.read_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/superceded/All sides bias scores.csv")

# %%
df
# Out:
#                      Provider  Bias_score Confidence Paywall  \
# 0                    AlterNet        -4.5     Medium       N
# 1                The Atlantic        -4.0       High    Some
# 2              Democracy Now!        -4.0        Low       N
# 3                 Daily Beast        -4.1       High    Some
# 4                    HuffPost        -4.3       High       N
# ..                        ...         ...        ...     ...
# 62  National Review (Opinion)         3.6     Medium    Some
# 63    New York Post (Opinion)         4.0        Low       N
# 64                    Newsmax         4.0     Medium    Some
# 65     Washington Free Beacon         4.0       High       N
# 66   One America News Network         3.1     Medium    Some
#
#                             Website  Classification
# 0         https://www.alternet.org/              -2
# 1      https://www.theatlantic.com/              -2
# 2     https://www.democracynow.org/              -2
# 3    https://www.thedailybeast.com/              -2
# 4         https://www.huffpost.com/              -2
# ..                              ...             ...
# 62  https://www.nationalreview.com/               2
# 63  https://www.nypost.com/opinion/               2
# 64         https://www.newsmax.com/               2
# 65      https://www.freebeacon.com/               2
# 66            https://www.oann.com/               2
#
# [67 rows x 6 columns]

# %%
mask = df["Confidence"] != "High"
mask
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 62     True
# 63     True
# 64     True
# 65    False
# 66     True
# Name: Confidence, Length: 67, dtype: bool

# %%
df = df[mask]

# %%
df.head()
# Out:
#          Provider  Bias_score Confidence Paywall  \
# 0        AlterNet        -4.5     Medium       N
# 2  Democracy Now!        -4.0        Low       N
# 5   The Intercept        -3.6        Low    Some
# 6         Jacobin        -4.0        Low    Some
# 7    Mother Jones        -4.0        Low       N
#
#                          Website  Classification
# 0      https://www.alternet.org/              -2
# 2  https://www.democracynow.org/              -2
# 5  https://www.theintercept.com/              -2
# 6    https://www.jacobinmag.com/              -2
# 7   https://www.motherjones.com/              -2

# %%
list_provider = []
for row in df["Website"]:
    list_provider.append(row)
list_provider
# Out:
# ['https://www.alternet.org/',
#  'https://www.democracynow.org/',
#  'https://www.theintercept.com/',
#  'https://www.jacobinmag.com/',
#  'https://www.motherjones.com/',
#  'https://www.newyorker.com/',
#  'https://www.thenation.com/',
#  'https://www.axios.com/',
#  'https://www.cnn.com/',
#  'https://www.theguardian.com/',
#  'https://www.insider.com/',
#  'https://www.nbcnews.com/',
#  'https://www.npr.org/',
#  'https://www.politico.com/',
#  'https://www.bbc.com/',
#  'https://www.forbes.com/',
#  'https://www.marketwatch.com/',
#  'https://www.newsnationnow.com/',
#  'https://www.thedispatch.com/',
#  'https://www.foxbusiness.com/',
#  'https://www.wsj.com/news/opinion/',
#  'https://www.washingtontimes.com/',
#  'https://www.theamericanconservative.com/',
#  'https://www.spectator.org/',
#  'https://www.theblaze.com/',
#  'https://www.cbn.com/',
#  'https://www.ijr.com/',
#  'https://www.nationalreview.com/',
#  'https://www.nypost.com/opinion/',
#  'https://www.newsmax.com/',
#  'https://www.oann.com/']

# %%
len(list_provider)
# Out:
# 31

# %% [markdown]
# ### scrape new list

# %%
from newspaper import Article
import newspaper
from textblob import TextBlob
import nltk

from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
import pandas as pd

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                # article.nlp()
                # v=sia.polarity_scores(article.text)
                # compound.append(v["compound"])
                # neg.append(v["neg"])
                # neu.append(v["neu"])
                # pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                # polarity.append(testimonial.sentiment.polarity)
                # subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags))#,compound)) #,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags'])#,'compound'])#,'neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = list_provider

new_data = news_scraper(link_lst)
# Out:
# links from https://www.alternet.org/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.democracynow.org/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.theintercept.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.jacobinmag.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.motherjones.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.newyorker.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from https://www.thenation.com/ = 4
# Link Failed -  https://www.thenation.com/ https:/www.thenation.com/issue/december-11-18-2023-issue/
# Link Failed -  https://thenation.com/ https:/www.thenation.com/issue/december-11-18-2023-issue/
# Link Failed -  http://www.thenation.com/ https:/www.thenation.com/issue/december-11-18-2023-issue/
# Total Links -  4
# **Finished Parsing**
# links from https://www.axios.com/ = 0
# Total Links -  4
# **Finished Parsing**
# links from https://www.cnn.com/ = 0
# Total Links -  4
# **Finished Parsing**
# links from https://www.theguardian.com/ = 1
# Total Links -  5
# **Finished Parsing**
# links from https://www.insider.com/ = 19
# Total Links -  24
# **Finished Parsing**
# links from https://www.nbcnews.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.npr.org/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.politico.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.bbc.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.forbes.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.marketwatch.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.newsnationnow.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.thedispatch.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.foxbusiness.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.wsj.com/news/opinion/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.washingtontimes.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.theamericanconservative.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.spectator.org/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.theblaze.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.cbn.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.ijr.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.nationalreview.com/ = 0
# Total Links -  24
# **Finished Parsing**
# links from https://www.nypost.com/opinion/ = 2
# Total Links -  26
# **Finished Parsing**
# links from https://www.newsmax.com/ = 5
# Total Links -  31
# **Finished Parsing**
# links from https://www.oann.com/ = 0
# Total Links -  31
# **Finished Parsing**

# %%
print(new_data['text'][2])
# Out:
# Until last month, some student loan borrowers were in the midst of a travel heyday.
#
# Pandemic regulations had loosened, borders had widely reopened, and repayments were still frozen.
#
# Some people were traveling more than ever — until payments resumed in October. Then reality sunk in.
#
# NEW LOOK Sign up to get the inside scoop on today’s biggest stories in markets, tech, and business — delivered daily. Read preview Loading Something is loading. Thanks for signing up! Access your favorite topics in a personalized feed while you're on the go. download the app Email address Sign up By clicking “Sign Up”, you accept our Terms of Service and Privacy Policy . You can opt-out at any time.
#
# Advertisement
#
# For people with a travel bug, the months between spring 2021 and October 2023 posed an unprecedented opportunity.
#
# It was a perfect storm: Student loan payments were on hold, frozen without interest, thanks to the Covid-19 outbreak the year prior. Many shifted to a hybrid schedule or could work entirely remotely. Pandemic restrictions were loosening up nationwide, and countries like France and England officially reopened their borders to tourists.
#
# Many borrowers had more freedom than ever — and hundreds of extra dollars burning a hole in their pockets — so some funneled their newfound independence and extra cash into travel.
#
# But with the resumption of student loan payments in October, travelers' budgets are tightening — and the pandemic-era dream of freewheeling revenge travel is crashing back down to earth.
#
# Advertisement
#
# Payments will affect how borrowers travel
#
# A recent survey by travel company Going, shared with Business Insider, found that 21% of respondents said they had student loans. Of those, about two-thirds — 63% — said monthly payments would affect how they travel.
#
# According to the personal finance website Bankrate, 28% of Gen Zers have student loan debt, compared with 43% of millennials. Twenty-one percent of Gen X has student loans, per the site. The average student loan debt is about $29,000 — and the American population owes $1.75 trillion in student debt, according to Forbes.
#
# Katy Nastro, one of Going's travel experts, said that while many travelers enjoyed high-budget international trips between 2021 and the start of 2023, many will begin to rethink what travel looks like for them in the coming months.
#
# "Moving forward into next year, a good portion of people who might've looked to take the same amount of trips that they did this year are now going to say, 'Well, maybe it's not really in the budget anymore,'" Nastro said. "They're probably going to look at what type of travel they want to do this year and then have to make some adjustments."
#
# Advertisement
#
# Of the student loan borrowers surveyed by Going, 38% said they'd have to be more budget-conscious during any upcoming trips, and 17% said they'd have to take fewer trips than they used to.
#
# Which takes priority: loans or travel?
#
# Throughout the pandemic, 25-year-old Katie Simony flew between her home in Colorado and her boyfriend's home in Minnesota at least once a month, if not every two weeks.
#
# Beyond commuting between states, Simony told BI she and her boyfriend would regularly take weekend trips, and she even swung a trip to France in 2022. By June last year, she said she had already used most of her PTO days.
#
# Katie Simony in Paris. Courtesy of Katie Simony
#
# However, that travel heyday is essentially over for Simony, who attended Grand Canyon University in Phoenix for two years starting in 2016. Now, she pays about $350 monthly in loans.
#
# Advertisement
#
# Simony said she didn't graduate from the university, making it all the more bitter to repay the loans.
#
# "I'm paying all this money back for something I'm not even using," she said. "It just feels like a huge, giant waste."
#
# "You get used to not having to make those payments for a few years," Simony continued. "And then, to have to put them back in your budget, it feels like you almost have to make the decision, 'Do I want to make my loan payment this month, or do I want to go home and see my family?'"
#
# In the coming months, we'll see a 'renormalization' of travel, experts say
#
# For the past few summers, it may have felt like everyone you know was in Europe. In many ways, that was kind of true, Nastro told BI. People were tired of being cooped up, had money to spare, and began focusing on splashy international vacations.
#
# Advertisement
#
# "They got their big-ticket trips out of the way," Nastro said. "Maybe they took one or two extra trips in the last 15 months because they hadn't been able to do so in a while due to the pandemic restrictions."
#
# One student loan borrower, 24-year-old Megan Rose, had that kind of year in 2022, visiting southern France and Seoul, South Korea. She bought her roughly $700 ticket to France two weeks beforehand after a friend asked if she could help housesit for a family member.
#
# That kind of last-minute, high-cost travel isn't in the cards these days, Rose said, in part due to her student loans. She also said that working two jobs has tightened her schedule, making it harder to pack up and go.
#
# Still, that budget change aligns with what Nastro envisions for the future of student loan borrowers' travel.
#
# Advertisement
#
# "I think this year we're going to see a more clear renormalization of travel," she said — meaning people will likely turn to domestic travel in 2024, as well as lean on cheaper destinations to get their travel fix.
#
# "It's a shame," Nastro said, "that student loan payments, for a notable amount of people, impact how they live their life."

# %%
df
# Out:
#                          Provider  Bias_score Confidence Paywall  \
# 0                        AlterNet       -4.50     Medium       N
# 2                  Democracy Now!       -4.00        Low       N
# 5                   The Intercept       -3.60        Low    Some
# 6                         Jacobin       -4.00        Low    Some
# 7                    Mother Jones       -4.00        Low       N
# 9                  The New Yorker       -4.20        Low    Some
# 11                     The Nation       -5.00        Low    Some
# 16                          Axios       -1.70     Medium       N
# 19                            CNN       -1.20     Medium       N
# 20                   The Guardian       -2.40     Medium       N
# 21                        Insider       -2.60     Medium    Some
# 22                       NBC News       -1.80     Medium       N
# 24                            NPR       -2.00     Medium       N
# 25                       Politico       -1.20     Medium       N
# 31                       BBC News       -0.80     Medium       N
# 33                         Forbes       -0.50        Low    Some
# 34                    MarketWatch       -0.30     Medium       N
# 35                     NewsNation        0.36        Low       N
# 41                   The Dispatch        2.00        Low    Some
# 43                   Fox Business        2.00     Medium       N
# 47  Wall Street Journal (Opinion)        1.80     Medium    Some
# 49               Washington Times        2.00     Medium    Some
# 50      The American Conservative        4.00     Medium       N
# 51         The American Spectator        4.00        Low    Some
# 53                      The Blaze        4.00        Low       N
# 54                            CBN        4.00        Low       N
# 61     Independent Journal Review        4.10     Medium    Some
# 62      National Review (Opinion)        3.60     Medium    Some
# 63        New York Post (Opinion)        4.00        Low       N
# 64                        Newsmax        4.00     Medium    Some
# 66       One America News Network        3.10     Medium    Some
#
#                                      Website  Classification
# 0                  https://www.alternet.org/              -2
# 2              https://www.democracynow.org/              -2
# 5              https://www.theintercept.com/              -2
# 6                https://www.jacobinmag.com/              -2
# 7               https://www.motherjones.com/              -2
# 9                 https://www.newyorker.com/              -2
# 11                https://www.thenation.com/              -2
# 16                    https://www.axios.com/              -1
# 19                      https://www.cnn.com/              -1
# 20              https://www.theguardian.com/              -1
# 21                  https://www.insider.com/              -1
# 22                  https://www.nbcnews.com/              -1
# 24                      https://www.npr.org/              -1
# 25                 https://www.politico.com/              -1
# 31                      https://www.bbc.com/               0
# 33                   https://www.forbes.com/               0
# 34              https://www.marketwatch.com/               0
# 35            https://www.newsnationnow.com/               0
# 41              https://www.thedispatch.com/               1
# 43              https://www.foxbusiness.com/               1
# 47         https://www.wsj.com/news/opinion/               1
# 49          https://www.washingtontimes.com/               1
# 50  https://www.theamericanconservative.com/               2
# 51                https://www.spectator.org/               2
# 53                 https://www.theblaze.com/               2
# 54                      https://www.cbn.com/               2
# 61                      https://www.ijr.com/               2
# 62           https://www.nationalreview.com/               2
# 63           https://www.nypost.com/opinion/               2
# 64                  https://www.newsmax.com/               2
# 66                     https://www.oann.com/               2
