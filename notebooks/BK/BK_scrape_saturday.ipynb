# %%
# !pip install newspaper3k
from newspaper import Article
import newspaper
from textblob import TextBlob
import nltk

from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
import pandas as pd
import numpy as np

# %%
list_full = ['http://www.theatlantic.com/',
 'http://www.thedailybeast.com/',
 'http://www.huffpost.com/',
 'http://www.msnbc.com/',
 'http://www.nytimes.com/',
 'http://www.slate.com/',
 'http://www.vox.com/',
 'http://www.abcnews.go.com/',
 'http://www.apnews.com/',
 'http://www.bloomberg.com/',
 'http://www.cbsnews.com/',
 'http://www.nytimes.com/']

# %%
list_1 = list_full[0:4]

# %%
list_2 = list_full[4:8]

# %%
list_3 = list_full[8:12]

# %% [markdown]
# ### first batch, 4 publishers

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = list_1

new_data_1 = news_scraper(link_lst)
# Out:
# links from http://www.theatlantic.com/ = 14
# Total Links -  14
# **Finished Parsing**
# links from http://www.thedailybeast.com/ = 7
# Total Links -  21
# **Finished Parsing**
# links from http://www.huffpost.com/ = 0
# Total Links -  21
# **Finished Parsing**
# links from http://www.msnbc.com/ = 33
# Link Failed -  https://www.msnbc.com/the-reidout/reidout-blog/jim-jordan-youtube-files-social-media-censorship-investigation-rcna127669
# Total Links -  54
# **Finished Parsing**

# %% [markdown]
# ### second batch, 4 publishers

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = list_2

new_data_2 = news_scraper(link_lst)
# Out:
# links from http://www.nytimes.com/ = 69
# Link Failed -  https://cooking.nytimes.com/recipes/1020153-indian-ish-baked-potatoes
# Total Links -  69
# **Finished Parsing**
# links from http://www.slate.com/ = 0
# Total Links -  69
# **Finished Parsing**
# links from http://www.vox.com/ = 2
# Total Links -  71
# **Finished Parsing**
# links from http://www.abcnews.go.com/ = 0
# Total Links -  71
# **Finished Parsing**

# %% [markdown]
# ### thirs patch, 4 publishers

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = list_3

new_data_3 = news_scraper(link_lst)
# Out:
# links from http://www.apnews.com/ = 102
# Link Failed -  https://apnews.com/article/kevin-durant-suns-top-10-scoring-leaders-a538a5cf49ef1e1844318b510d948bde
# Total Links -  102
# **Finished Parsing**
# links from http://www.bloomberg.com/ = 159
# Total Links -  261
# **Finished Parsing**
# links from http://www.cbsnews.com/ = 120
# Total Links -  381
# **Finished Parsing**
# links from http://www.nytimes.com/ = 0
# Total Links -  381
# **Finished Parsing**

# %%
concat_df = pd.concat([new_data_1,new_data_2,new_data_3], axis=0)
concat_df.head()
# Out:
#                                                 link  \
# 0  https://www.theatlantic.com/ideas/archive/2023...
# 1  https://www.theatlantic.com/newsletters/archiv...
# 2  https://www.theatlantic.com/photo/2023/12/2023...
# 3  https://www.theatlantic.com/ideas/archive/2023...
# 4  https://www.theatlantic.com/politics/archive/2...
#
#                        pdate  \
# 0  2023-12-01 23:56:00+00:00
# 1  2023-12-01 23:42:00+00:00
# 2        2023-12-20 00:00:00
# 3  2023-12-01 18:26:40+00:00
# 4  2023-12-01 17:29:00+00:00
#
#                                                title            author  \
# 0  Sandra Day O’Connor, the Mom Next Door—And So ...  [Jonathan Rauch]
# 1                 The Curtain Falls on George Santos     [Lora Kelley]
# 2               2023 Space-Telescope Advent Calendar     [Alan Taylor]
# 3              Expelling George Santos Was a Mistake     [Adam Serwer]
# 4  George Santos Was Finally Too Much for Republi...  [Russell Berman]
#
#                                                 text  \
# 0  We were neighbors when I was growing up in Pho...
# 1  I spoke with my colleague Russell Berman about...
# 2  Once again, it’s time for one of my favorite h...
# 3  Forcing the New York representative out of the...
# 4  So long, George Santos, we hardly knew ye—and ...
#
#                                             keywords tags  compound    neg  \
# 0  [mrs, republican, supreme, needed, doorand, da...   {}    0.9941  0.066
# 1  [lied, majority, republican, george, york, cur...   {}    0.8133  0.075
# 2  [universe, traditions, images, 2023, day, chri...   {}    0.9894  0.000
# 3  [voters, george, york, surreal, overturn, sant...   {}   -0.9798  0.111
# 4  [vote, majority, republican, george, york, par...   {}   -0.9979  0.133
#
#      neu    pos  polarity  subjectivity
# 0  0.826  0.108  0.155693      0.450382
# 1  0.845  0.080  0.030104      0.437948
# 2  0.734  0.266  0.369697      0.489588
# 3  0.845  0.044  0.046061      0.542865
# 4  0.806  0.061  0.019869      0.469669

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 0 to 379
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          503 non-null    object
#  1   pdate         329 non-null    object
#  2   title         503 non-null    object
#  3   author        503 non-null    object
#  4   text          503 non-null    object
#  5   keywords      503 non-null    object
#  6   tags          503 non-null    object
#  7   compound      503 non-null    float64
#  8   neg           503 non-null    float64
#  9   neu           503 non-null    float64
#  10  pos           503 non-null    float64
#  11  polarity      503 non-null    float64
#  12  subjectivity  503 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 55.0+ KB

# %%
# !pwd
# Out:
# /Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/notebooks

# %%
concat_df.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/sat_bk_scrape.csv")

# %%
zoe_list = ['http://www.propublica.org/',
 'http://www.time.com/',
 'http://www.washingtonpost.com/',
 'http://www.usatoday.com/',
 'http://www.yahoo.com/',
 'http://www.csmonitor.com/',
 'http://www.newsweek.com/',
 'http://www.reuters.com/',
 'http://www.realclearpolitics.com/',
 'http://www.thehill.com/',
 'http://www.wsj.com/',
 'http://www.theepochtimes.com/']

# %%
len(zoe_list)
# Out:
# 12

# %%
zoe_list_1 = zoe_list[0:6]
zoe_list_2 = zoe_list[6:12]

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = zoe_list_1

new_data_z_1 = news_scraper(link_lst)
# Out:
# links from http://www.propublica.org/ = 48
# Total Links -  48
# **Finished Parsing**
# links from http://www.time.com/ = 110
# Total Links -  158
# **Finished Parsing**
# links from http://www.washingtonpost.com/ = 80
# Link Failed -  https://www.washingtonpost.com/sports/2023/12/01/kevin-durant-top-10-all-time-scoring/
# Link Failed -  https://www.washingtonpost.com/world/2023/11/30/how-tiktokers-swifties-became-political-power-brokers-guatemala/
# Link Failed -  https://www.washingtonpost.com/weather/2023/12/01/kona-storms-mountain-snows-rains/
# Link Failed -  https://www.washingtonpost.com/nation/2023/12/01/jacob-lagrone-viral-wedding-century-indicted-prison-tiktok/
# Total Links -  238
# **Finished Parsing**
# links from http://www.usatoday.com/ = 243
# Link Failed -  https://cm.usatoday.com/news/nation/
# Link Failed -  https://cm.usatoday.com/news/investigations/
# Link Failed -  https://cm.usatoday.com/story/news/politics/2023/12/01/what-to-know-about-the-life-and-legacy-of-sandra-day-oconnor/71766827007/
# Link Failed -  https://cm.usatoday.com/story/news/nation/2023/12/01/person-fire-protest-israeli-consulate-atlanta/71773315007/
# Link Failed -  https://cm.usatoday.com/story/news/politics/2023/12/01/george-santos-expelled-house-ethics/71720258007/
# Link Failed -  https://cm.usatoday.com/story/entertainment
/
# Link Failed -  http://cm.usatoday.com/story/entertainment/movies/2023/12/01/may-december-ending-explained-spoilers/71756036007/
# Link Failed -  http://cm.usatoday.com/story/entertainment/celebrities/2023/12/01/macaulay-culkin-brenda-song-step-out-with-their-kids/71772421007/
# Link Failed -  http://cm.usatoday.com/story/sports/olympics/2023/12/01/klete-keller-sentencing-olympian-probation-jan-6-case/71717890007/
# Link Failed -  http://cm.usatoday.com/story/news/world/israel-hamas/2023/12/01/israel-hamas-war-gaza-live-updates/71764680007/
# Link Failed -  http://cm.usatoday.com/story/entertainment/celebrities/2023/12/01/jussie-smollett-loses-court-appeal/71775206007/
# Link Failed -  http://cm.usatoday.com/story/news/factcheck/2023/12/01/no-video-does-not-prove-idf-tanks-shot-at-israeli-citizens-fact-check/71759408007/
# Link Failed -  http://cm.usatoday.com/story/life/health-wellness/2023/12/01/christmas-tree-syndrome/71766427007/
# Link Failed -  http://cm.usatoday.com/story/news/investigations/2023/12/01/where-did-ammon-bundy-go-vermont-palestinian-shooting/71742764007/
# Link Failed -  http://cm.usatoday.com/story/sports/ncaaf/pac12/2023/12/01/washington-oregon-pac-12-title-college-football-playoff/71757588007/
# Link Failed -  http://cm.usatoday.com/story/tech/2023/12/01/ai-for-holiday-shopping-experiment/71740774007/
# Link Failed -  http://cm.usatoday.com/story/entertainment/tv/2023/12/01/ladies-of-the-eighties-diva-christmas-lifetime-movie/71724037007/
# Link Failed -  http://cm.usatoday.com/story/money/2023/12/01/mars-child-labor-cbs-investigation-findings-response/71769249007/
# Link Failed -  http://cm.usatoday.com/story/graphics/2023/11/30/high-mortgage-rates-hurt-housing-affordability/71656296007/
# Link Failed -  http://www.usatoday.com/story/nletter/2023/12/01/migrant-border-trump-mexico-immigrant-border-patrol-texas/71729133007/
# Link Failed -  http://www.usatoday.com/story/nletter/2023/11/21/gun-los-angeles-mexico/71617063007/
# Total Links -  481
# **Finished Parsing**
# links from http://www.yahoo.com/ = 0
# Total Links -  481
# **Finished Parsing**
# links from http://www.csmonitor.com/ = 338
# Link Failed -  http://www.csmonitor.com/%20https://www.c-span.org/video/?532060-3/house-session-part-2
# Link Failed -  https://www.wsj.com/world/middle-east/militants-behind-israel-attack-raised-millions-in-crypto-b9134b7a
# Link Failed -  https://www.theafricareport.com/314565/kenya-environmentalists-blast-rutos-double-speak-on-forest-conservation/
# Link Failed -  https://www.sciencedirect.com/science/article/abs/pii/S0048969720348737
# Total Links -  819
# **Finished Parsing**

# %%
def news_scraper(link_):

    link=[]
    title=[]
    text=[]
    author=[]
    pdate=[]
    keywords=[]
    tags=[]
    compound=[]
    neg=[]
    neu=[]
    pos=[]
    polarity=[]
    subjectivity=[]

    for x in link_:
        cnn_pape = newspaper.build(x,language='en',memorize='false')
        print("links from",x,"=",len(cnn_pape.articles))
        for article in cnn_pape.articles:
            try:
                link.append(article.url)
                article.download()
                article.parse()
                article.nlp()
                v=sia.polarity_scores(article.text)
                compound.append(v["compound"])
                neg.append(v["neg"])
                neu.append(v["neu"])
                pos.append(v["pos"])
                testimonial = TextBlob(article.text)
                polarity.append(testimonial.sentiment.polarity)
                subjectivity.append(testimonial.sentiment.subjectivity)
                title.append(article.title)
                text.append(article.text)
                author.append(article.authors)
                pdate.append(article.publish_date)
                keywords.append(article.keywords)
                tags.append(article.tags)
            except:
                print('Link Failed - ', article.url)
                continue
        print("Total Links - " , len(link))
        print("**Finished Parsing**")
        
    tt=list(zip(link,pdate,title,author,text,keywords,tags,compound,neg,neu,pos,polarity,subjectivity))
    d1=pd.DataFrame(tt,columns=['link','pdate','title','author','text','keywords','tags','compound','neg','neu','pos','polarity','subjectivity'])
    
    return d1


link_lst = zoe_list_2

new_data_z_2 = news_scraper(link_lst)
# Out:
# links from http://www.newsweek.com/ = 0
# Total Links -  0
# **Finished Parsing**
# links from http://www.reuters.com/ = 284
# Link Failed -  http://www.reuters.com/sports/soccer/bayern-munich-vs-union-berlin-postponed-due-snow-2023-12-02/
# Link Failed -  http://www.reuters.com/sports/golf/lee-hoshino-set-up-final-round-duel-australian-open-2023-12-02/
# Link Failed -  http://www.reuters.com/sports/nba-roundup-magic-tie-team-mark-with-9th-straight-win-2023-12-02/
# Link Failed -  http://www.reuters.com/sports/tahiti-villagers-say-barge-surf-tower-build-damages-reef-2023-12-02/
# Link Failed -  http://www.reuters.com/world/our-oddest-photos-2023-2023-12-01-2/
# Link Failed -  https://reuters.com/sports/soccer/bayern-munich-vs-union-berlin-postponed-due-snow-2023-12-02/
# Link Failed -  https://reuters.com/sports/golf/lee-hoshino-set-up-final-round-duel-australian-open-2023-12-02/
# Link Failed -  https://reuters.com/sports/nba-roundup-magic-tie-team-mark-with-9th-straight-win-2023-12-02/
# Link Failed -  https://reuters.com/sports/tahiti-villagers-say-barge-surf-tower-build-damages-reef-2023-12-02/
# Link Failed -  https://reuters.com/world/our-oddest-photos-2023-2023-12-01-2/
# Link Failed -  http://www.reuters.com/sports/britain-wins-litter-picking-world-cup-with-load-rubbish-2023-11-24/
# Link Failed -  https://www.reuters.com/sports/soccer/bayern-munich-vs-union-berlin-postponed-due-snow-2023-12-02/
# Link Failed -  https://www.reuters.com/sports/golf/lee-hoshino-set-up-final-round-duel-australian-open-2023-12-02/
# Link Failed -  https://www.reuters.com/sports/nba-roundup-magic-tie-team-mark-with-9th-straight-win-2023-12-02/
# Link Failed -  https://www.reuters.com/sports/tahiti-villagers-say-barge-surf-tower-build-damages-reef-2023-12-02/
# Link Failed -  https://www.reuters.com/world/our-oddest-photos-2023-2023-12-01-2/
# Total Links -  284
# **Finished Parsing**
# links from http://www.realclearpolitics.com/ = 0
# Total Links -  284
# **Finished Parsing**
# links from http://www.thehill.com/ = 0
# Total Links -  284
# **Finished Parsing**
# links from http://www.wsj.com/ = 83
# Link Failed -  https://www.wsj.com/news/latest-headlines?mod=wsjheader
# Link Failed -  https://www.wsj.com/news/latest-headlines?mod=nav_top_section
# Link Failed -  https://www.wsj.com/news/types/obituaries?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/business/small-business-marketing?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/business/media?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/cfo-journal?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/cio-journal?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/cmo-today?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/logistics-report?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/risk-compliance-journal?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/heard-on-the-street?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/journal-reports?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/types/capital-account?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/author/8003?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/author/7872?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/author/julie-jargon?mod=nav_top_subsection
# Link Failed -  https://www.wsj.com/news/author
cmt=1
# Link Failed -  http://www.theepochtimes.com/epochtv/heres-the-problem-with-mainstream-heart-diabetes-and-alzheimers-medicine-dr-paul-marik-florida-summit-5539142
# Link Failed -  http://www.theepochtimes.com/epochtv/how-big-pharma-used-the-tobacco-industry-playbook-dr-pierre-kory-florida-summit-5538604
# Link Failed -  http://www.theepochtimes.com/epochtv/we-knew-mrna-vaccines-could-get-into-brain-and-ovaries-since-2012-dr-richard-urso-florida-summit-5538433
# Link Failed -  http://www.theepochtimes.com/epochtv/heres-what-happened-in-the-trump-white-house-when-covid-hit-dr-steven-hatfill-florida-summit-5538351
# Link Failed -  http://www.theepochtimes.com/epochtv/laying-a-diy-concrete-walkway-5538982
# Link Failed -  https://es.theepochtimes.com/pfizer-mintio-eficacia-contra-covid-texasdominio-mental-en-las-redes-socialescarne-sintetica_1209550.html
# Link Failed -  https://es.theepochtimes.com/pico-de-muertes-de-lideres-chinos-en-ola-de-infecciones_1209485.html
# Link Failed -  https://es.theepochtimes.com/corte-de-apelaciones-de-nueva-york-restablece-orden-de-silencio-a-trump-ntd-noticias-1-de-diciembre_1209153.html
# Link Failed -  https://es.theepochtimes.com/investigan-a-juez-vinculada-a-biden-y-obama-mascarillascontagios-estudio-alerta-terapia-genica_1209112.html
# Link Failed -  https://es.theepochtimes.com/agencia-federal-informa-mas-de-400-sismos-cerca-del-monte-santa-helena_1200166.html
# Link Failed -  http://www.theepochtimes.com/epochtv/heres-the-problem-with-mainstream-heart-diabetes-and-alzheimers-medicine-dr-paul-marik-florida-summit-5539142?cmt=1
# Link Failed -  http://www.theepochtimes.com/epochtv/how-big-pharma-used-the-tobacco-industry-playbook-dr-pierre-kory-florida-summit-5538604?cmt=1
# Link Failed -  https://staging.theepochtimes.com/health/the-essential-guide-to-tinnitus-symptoms-causes-treatments-and-natural-approaches-5323826
# Link Failed -  https://staging.theepochtimes.com/health/the-essential-guide-to-alzheimers-disease-symptoms-causes-treatments-and-natural-remedies-5245289
# Total Links -  2286
# **Finished Parsing**

# %%
concat_z = pd.concat([new_data_z_1, new_data_z_2], axis=0)

# %%
concat_z
# Out:
#                                                    link pdate  \
# 0     https://www.propublica.org/article/west-virgin...  None
# 1     https://www.propublica.org/article/texas-judge...  None
# 2     https://www.propublica.org/article/senate-judi...  None
# 3     https://www.propublica.org/article/senators-qu...  None
# 4     https://www.propublica.org/article/clarence-th...  None
# ...                                                 ...   ...
# 2128  https://es.theepochtimes.com/esa-es-mi-nina-pa...  None
# 2129  https://es.theepochtimes.com/terminos-y-condic...  None
# 2130  http://www.theepochtimes.com/shenyun/shen-yun-...  None
# 2131  http://www.theepochtimes.com/shenyun/shen-yun-...  None
# 2132  http://www.theepochtimes.com/shenyun/missionar...  None
#
#                                                   title  \
# 0     West Virginians Could Get Stuck Cleaning Up th...
# 1     Texas Judge Orders Release of Uvalde Shooting ...
# 2     Senate Committee Authorizes Subpoenas of Harla...
# 3     Senators Question KPMG Role in Microsoft Profi...
# 4     Clarence Thomas Secretly Accepted Luxury Trips...
# ...                                                 ...
# 2128  Rolling Blackouts Could Impact South Again Thi...
# 2129  Brent Slips Toward $80/bbl Ahead of OPEC+ Meeting
# 2130  Greens Leader Backs Blockade of the World's La...
# 2131  Texas’s Green Energy Dream Is Risking Its Elec...
# 2132  Brent Steady Ahead of OPEC+ Oil Production Dec...
#
#                                                  author  \
# 0                                        [Ken Ward Jr.]
# 1                                        [Zach Despart]
# 2     [Andy Kroll, Andy Kroll Is A Propublica Report...
# 3     [Paul Kiel, Paul Kiel Covers Business, Consume...
# 4     [Joshua Kaplan, Justin Elliott, Alex Mierjeski...
# ...                                                 ...
# 2128                                                 []
# 2129                                                 []
# 2130                                                 []
# 2131                                                 []
# 2132                                                 []
#
#                                                    text  \
# 0     An excavated mountain and highwalls on the wes...
# 1     Texas Judge Orders Release of Uvalde Shooting ...
# 2     Series: Friends of the Court: SCOTUS Justices’...
# 3     Series: Gutting the IRS: Who Wins When a Cruci...
# 4     First image: Clarence Thomas in October 2022. ...
# ...                                                 ...
# 2128  As winter approaches, concerns about the relia...
# 2129  LONDON—Oil prices slipped on Monday, with Bren...
# 2130  Hundreds of protestors paddled out on kayaks, ...
# 2131  Since Texas weathered its second-hottest summe...
# 2132  LONDON—Brent crude futures were steady on Frid...
#
#                                                keywords  \
# 0     [lexington, cleaning, industrys, virginians, m...
# 1     [release, texas, records, organizations, dps, ...
# 2     [subpoenas, probe, committee, supreme, thomas,...
# 3     [irs, microsoft, puerto, question, senators, t...
# 4     [accepted, justice, luxury, crows, thomas, cou...
# ...                                                 ...
# 2128  [electric, south, rolling, challenges, demand,...
# 2129  [analysts, meeting, cuts, prices, ahead, crude...
# 2130  [despite, backs, labor, power, arrests, coal, ...
# 2131  [electric, texas, mr, dream, texass, demand, g...
# 2132  [analysts, oil, ahead, production, crude, stea...
#
#                                                    tags  compound    neg  \
# 0                                                    {}   -0.9993  0.104
# 1                                                    {}   -0.8769  0.080
# 2                                                    {}    0.9981  0.049
# 3                                                    {}    0.9990  0.030
# 4                                                    {}    0.9999  0.026
# ...                                                 ...       ...    ...
# 2128                      {TVA, Tennessee, south, NERC}    0.9630  0.077
# 2129                                      {Oil, global}   -0.9781  0.117
# 2130  {climate activism, Port of Newcastle, climate ...    0.6454  0.080
# 2131                                                 {}    0.9994  0.055
# 2132                                      {Oil, global}    0.7964  0.095
#
#         neu    pos  polarity  subjectivity
# 0     0.824  0.072  0.055620      0.404267
# 1     0.849  0.071  0.096415      0.351263
# 2     0.845  0.106  0.065883      0.328966
# 3     0.807  0.163  0.104960      0.502734
# 4     0.864  0.110  0.107636      0.403050
# ...     ...    ...       ...           ...
# 2128  0.822  0.101  0.079146      0.503619
# 2129  0.829  0.054 -0.084829      0.385684
# 2130  0.839  0.081  0.100724      0.367045
# 2131  0.832  0.113  0.086781      0.466977
# 2132  0.789  0.116 -0.032980      0.455404
#
# [2900 rows x 13 columns]

# %%
concat_z.to_csv("/Users/barnabykempster/code/zulu-tango/news_and_echo_bubbles/raw_data/sat_zt_scrape.csv")
